# %%
import pandas as pd
teams_df =pd.read_csv("C:/Users/Ros/Desktop/JDC/mini project/archive (1)/team_info.csv")

# %%
teams_df
# Out:
#     team_id  franchiseId     shortName        teamName abbreviation  \
# 0         1           23    New Jersey          Devils          NJD
# 1         4           16  Philadelphia          Flyers          PHI
# 2        26           14   Los Angeles           Kings          LAK
# 3        14           31     Tampa Bay       Lightning          TBL
# 4         6            6        Boston          Bruins          BOS
# 5         3           10    NY Rangers         Rangers          NYR
# 6         5           17    Pittsburgh        Penguins          PIT
# 7        17           12       Detroit       Red Wings          DET
# 8        28           29      San Jose          Sharks          SJS
# 9        18           34     Nashville       Predators          NSH
# 10       23           20     Vancouver         Canucks          VAN
# 11       16           11       Chicago      Blackhawks          CHI
# 12        9           30        Ottawa        Senators          OTT
# ...

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   team_id       33 non-null     int64
#  1   franchiseId   33 non-null     int64
#  2   shortName     33 non-null     object
#  3   teamName      33 non-null     object
#  4   abbreviation  33 non-null     object
#  5   link          33 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.7+ KB

# %%
teams_df.describe()
# Out:
#          team_id  franchiseId
# count  33.000000    33.000000
# mean   18.909091    22.969697
# std    13.789406    10.038939
# min     1.000000     1.000000
# 25%     9.000000    16.000000
# 50%    17.000000    24.000000
# 75%    25.000000    31.000000
# max    54.000000    38.000000

# %%
games= pd.read_csv("C:/Users/Ros/Desktop/JDC/mini project/archive (1)/game.csv")
games.head(50)
# Out:
#        game_id    season type         date_time_GMT  away_team_id  \
# 0   2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1   2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2   2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3   2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4   2017020586  20172018    R  2017-12-30T03:00:00Z            20
# 5   2016020610  20162017    R  2017-01-10T00:30:00Z            15
# 6   2015020606  20152016    R  2016-01-08T03:30:00Z            10
# 7   2017020240  20172018    R  2017-11-10T03:00:00Z            23
# 8   2017020624  20172018    R  2018-01-05T02:00:00Z            29
# 9   2015020346  20152016    R  2015-11-29T00:00:00Z            22
# 10  2017020221  20172018    R  2017-11-07T01:30:00Z            52
# 11  2016020298  20162017    R  2016-11-24T03:30:00Z             2
# 12  2017020731  20172018    R  2018-01-23T02:00:00Z             2
# ...

# %%
games.columns
# Out:
# Index(['game_id', 'season', 'type', 'date_time_GMT', 'away_team_id',
#        'home_team_id', 'away_goals', 'home_goals', 'outcome',
#        'home_rink_side_start', 'venue', 'venue_link', 'venue_time_zone_id',
#        'venue_time_zone_offset', 'venue_time_zone_tz'],
#       dtype='object')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 26305 non-null  int64
#  1   season                  26305 non-null  int64
#  2   type                    26305 non-null  object
#  3   date_time_GMT           26305 non-null  object
#  4   away_team_id            26305 non-null  int64
#  5   home_team_id            26305 non-null  int64
#  6   away_goals              26305 non-null  int64
#  7   home_goals              26305 non-null  int64
#  8   outcome                 26305 non-null  object
#  9   home_rink_side_start    25109 non-null  object
#  10  venue                   26305 non-null  object
#  11  venue_link              26305 non-null  object
#  12  venue_time_zone_id      26305 non-null  object
#  13  venue_time_zone_offset  26305 non-null  int64
# ...

# %%
games.describe()
# Out:
#             game_id        season  away_team_id  home_team_id    away_goals  \
# count  2.630500e+04  2.630500e+04  26305.000000  26305.000000  26305.000000
# mean   2.010765e+09  2.010945e+07     16.879377     16.881429      2.687968
# std    6.073568e+06  6.073849e+04     11.184920     11.205625      1.619068
# min    2.000020e+09  2.000200e+07      1.000000      1.000000      0.000000
# 25%    2.006020e+09  2.006201e+07      8.000000      8.000000      1.000000
# 50%    2.011021e+09  2.011201e+07     16.000000     16.000000      3.000000
# 75%    2.016030e+09  2.016202e+07     24.000000     24.000000      4.000000
# max    2.019041e+09  2.019202e+07     90.000000     90.000000     11.000000
#
#          home_goals  venue_time_zone_offset
# count  26305.000000            26305.000000
# mean       2.958981               -5.066147
# std        1.689031                1.210145
# min        0.000000               -8.000000
# 25%        2.000000               -6.000000
# ...

# %%
games
# Out:
#           game_id    season type         date_time_GMT  away_team_id  \
# 0      2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1      2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2      2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3      2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4      2017020586  20172018    R  2017-12-30T03:00:00Z            20
# ...           ...       ...  ...                   ...           ...
# 26300  2018030415  20182019    P  2019-06-07T00:00:00Z            19
# 26301  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26302  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26303  2018030417  20182019    P  2019-06-13T00:00:00Z            19
# 26304  2018030417  20182019    P  2019-06-13T00:00:00Z            19
#
#        home_team_id  away_goals  home_goals       outcome  \
# 0                16           4           7  home win REG
# ...

# %%
# Convert 'date_time_GMT' column to datetime format
games['date_time_GMT'] = pd.to_datetime(games['date_time_GMT'], format='%Y-%m-%dT%H:%M:%SZ')

# Convert datetime format to 'mm-dd-yyyy hh:mm' format
games['date_time_GMT'] = games['date_time_GMT'].dt.strftime('%m-%d-%Y %H:%M')

# Display the DataFrame with the updated 'date_time_GMT' column
#print(games)
games.head(50)
# Out:
#        game_id    season type     date_time_GMT  away_team_id  home_team_id  \
# 0   2016020045  20162017    R  10-19-2016 00:30             4            16
# 1   2017020812  20172018    R  02-07-2018 00:00            24             7
# 2   2015020314  20152016    R  11-24-2015 01:00            21            52
# 3   2015020849  20152016    R  02-17-2016 00:00            52            12
# 4   2017020586  20172018    R  12-30-2017 03:00            20            24
# 5   2016020610  20162017    R  01-10-2017 00:30            15             8
# 6   2015020606  20152016    R  01-08-2016 03:30            10            26
# 7   2017020240  20172018    R  11-10-2017 03:00            23            24
# 8   2017020624  20172018    R  01-05-2018 02:00            29            21
# 9   2015020346  20152016    R  11-29-2015 00:00            22             5
# 10  2017020221  20172018    R  11-07-2017 01:30            52            25
# ...

# %%
venue_df=games[['venue','venue_time_zone_id','venue_time_zone_offset', 'venue_time_zone_tz', 'venue_link']]
venue_df
# Out:
#                    venue   venue_time_zone_id  venue_time_zone_offset  \
# 0          United Center      America/Chicago                      -5
# 1         KeyBank Center     America/New_York                      -4
# 2             MTS Centre     America/Winnipeg                      -5
# 3              PNC Arena     America/New_York                      -4
# 4           Honda Center  America/Los_Angeles                      -7
# ...                  ...                  ...                     ...
# 26300          TD Garden     America/New_York                      -5
# 26301  Enterprise Center      America/Chicago                      -6
# 26302  Enterprise Center      America/Chicago                      -6
# 26303          TD Garden     America/New_York                      -5
# 26304          TD Garden     America/New_York                      -5
#
#       venue_time_zone_tz           venue_link
# 0                    CDT  /api/v1/venues/null
# ...

# %%
venue_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   venue                   26305 non-null  object
#  1   venue_time_zone_id      26305 non-null  object
#  2   venue_time_zone_offset  26305 non-null  int64
#  3   venue_time_zone_tz      26305 non-null  object
#  4   venue_link              26305 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.0+ MB

# %%
games_teams_stats= pd.read_csv("C:/Users/Ros/Desktop/JDC/mini project/archive (1)/game_teams_stats.csv")

# %%
games_teams_stats
# Out:
#           game_id  team_id   HoA    won settled_in        head_coach  goals  \
# 0      2016020045        4  away  False        REG      Dave Hakstol    4.0
# 1      2016020045       16  home   True        REG  Joel Quenneville    7.0
# 2      2017020812       24  away   True         OT     Randy Carlyle    4.0
# 3      2017020812        7  home  False         OT      Phil Housley    3.0
# 4      2015020314       21  away   True        REG       Patrick Roy    4.0
# ...           ...      ...   ...    ...        ...               ...    ...
# 52605  2018030416       19  home  False        REG      Craig Berube    1.0
# 52606  2018030417       19  away   True        REG      Craig Berube    4.0
# 52607  2018030417        6  home  False        REG     Bruce Cassidy    1.0
# 52608  2018030417       19  away   True        REG      Craig Berube    4.0
# 52609  2018030417        6  home  False        REG     Bruce Cassidy    1.0
#
# ...

# %%
games_teams_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52610 entries, 0 to 52609
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 52610 non-null  int64
#  1   team_id                 52610 non-null  int64
#  2   HoA                     52610 non-null  object
#  3   won                     52610 non-null  bool
#  4   settled_in              52610 non-null  object
#  5   head_coach              52582 non-null  object
#  6   goals                   52602 non-null  float64
#  7   shots                   52602 non-null  float64
#  8   hits                    47682 non-null  float64
#  9   pim                     52602 non-null  float64
#  10  powerPlayOpportunities  52602 non-null  float64
#  11  powerPlayGoals          52602 non-null  float64
#  12  faceOffWinPercentage    30462 non-null  float64
#  13  giveaways               47682 non-null  float64
# ...

# %%
games_teams_stats.derscribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\3359581457.py in ?()
# ----> 1 games_teams_stats.derscribe()
#
# c:\Users\Ros\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'derscribe'

# %%
coach= games_teams_stats[['head_coach','team_id']]
coach['head_coach'].unique()
# Out:
# array(['Dave Hakstol', 'Joel Quenneville', 'Randy Carlyle',
#        'Phil Housley', 'Patrick Roy', 'Paul Maurice', 'Bill Peters',
#        'Glen Gulutzan', 'Barry Trotz', 'Michel Therrien', 'Mike Babcock',
#        'Darryl Sutter', 'Travis Green', 'John Tortorella', 'Jared Bednar',
#        'Todd McLellan', 'Mike Johnston', 'Ken Hitchcock', 'Jack Capuano',
#        'Doug Weight', 'Rick Tocchet', 'Dave Tippett', 'John Hynes',
#        'Mike Sullivan', 'Jon Cooper', 'Bruce Boudreau', 'Peter DeBoer',
#        'Claude Julien', 'Peter Laviolette', 'Guy Boucher', 'Guy Charron',
#        'Bob Hartley', 'Gerard Gallant', 'Bruce Cassidy', 'Bob Boughner',
#        'John Torchetti', 'John Stevens', 'Alain Vigneault', 'Lindy Ruff',
#        'Jeff Blashill', 'Bill Barber', 'Dan Bylsma', 'Willie Desjardins',
#        'Tom Rowe', 'Mike Yeo', 'Dave Cameron', 'Marc Crawford',
#        'Todd Richards', 'Bob Francis', 'Craig Hartsburg', 'Curt Fraser',
# ...

# %%
coach['head_coach'].nunique()
# Out:
# 146

# %%
coach
# Out:
#              head_coach  team_id
# 0          Dave Hakstol        4
# 1      Joel Quenneville       16
# 2         Randy Carlyle       24
# 3          Phil Housley        7
# 4           Patrick Roy       21
# ...                 ...      ...
# 52605      Craig Berube       19
# 52606      Craig Berube       19
# 52607     Bruce Cassidy        6
# 52608      Craig Berube       19
# 52609     Bruce Cassidy        6
#
# [52610 rows x 2 columns]

# %%
coach_df= coach[['head_coach','team_id']].drop_duplicates()
coach_df
# Out:
#              head_coach  team_id
# 0          Dave Hakstol        4
# 1      Joel Quenneville       16
# 2         Randy Carlyle       24
# 3          Phil Housley        7
# 4           Patrick Roy       21
# ...                 ...      ...
# 49241      Scott Gordon        4
# 50251        Jon Cooper       87
# 50253      Paul Maurice       89
# 50677        Bob Murray       24
# 51180     Marc Crawford        9
#
# [252 rows x 2 columns]

# %%
#coach_df= coach_df.reset_index(drop=True)
coach_df.head(50)
# Out:
#             head_coach  team_id
# 0         Dave Hakstol        4
# 1     Joel Quenneville       16
# 2        Randy Carlyle       24
# 3         Phil Housley        7
# 4          Patrick Roy       21
# 5         Paul Maurice       52
# 7          Bill Peters       12
# 8        Glen Gulutzan       20
# 10         Barry Trotz       15
# 11     Michel Therrien        8
# 12        Mike Babcock       10
# 13       Darryl Sutter       26
# 14        Travis Green       23
# 16     John Tortorella       29
# 17        Jared Bednar       21
# 18       Todd McLellan       22
# 19       Mike Johnston        5
# 21       Ken Hitchcock       25
# 22        Jack Capuano        2
# 24         Doug Weight        2
# 25        Rick Tocchet       53
# 27        Dave Tippett       53
# 31          John Hynes        1
# 32       Mike Sullivan        5
# 34          Jon Cooper       14
# 41      Bruce Boudreau       30
# 47        Peter DeBoer       28
# 48       Claude Julien        6
# ...

# %%
s_coach_df= coach_df.sort_values(by='head_coach')
s_coach_df.head(50)
# Out:
#              head_coach  team_id
# 7527         Adam Oates        1
# 9957         Adam Oates       15
# 24918         Al Arbour        2
# 29030        Al MacNeil       20
# 44019  Alain Nasreddine        1
# 42369   Alain Vigneault        4
# 109     Alain Vigneault        3
# 36145   Alain Vigneault        8
# 10081   Alain Vigneault       23
# 36158      Alpo Suhonen       16
# 18925       Andy Murray       19
# 3779        Andy Murray       26
# 21293     Barry Melrose       14
# 4430        Barry Trotz       18
# 10          Barry Trotz       15
# 42373       Barry Trotz        2
# 131         Bill Barber        4
# 7           Bill Peters       12
# 42348       Bill Peters       20
# 98         Bob Boughner       13
# 44287      Bob Boughner       28
# 1109        Bob Francis       27
# 21329        Bob Gainey        8
# 262         Bob Hartley       21
# 66          Bob Hartley       20
# 23924       Bob Hartley       11
# 50677        Bob Murray       24
# ...

# %%
s_coach_df.tail(50)
# Out:
#               head_coach  team_id
# 28714      Robbie Ftorek        6
# 42343    Rod Brind'Amour       12
# 39247      Roger Neilson        9
# 6773             Ron Low        3
# 9966         Ron Rolston        7
# 23749         Ron Wilson       28
# 10360         Ron Wilson       15
# 13926         Ron Wilson       10
# 13907       Scott Arniel       29
# 14240       Scott Gordon        2
# 49241       Scott Gordon        4
# 36038      Scotty Bowman       17
# 43668      Sheldon Keefe       10
# 36053       Steve Ludzik       14
# 31145     Steve Stirling        2
# 7521           Ted Nolan        7
# 23812          Ted Nolan        2
# 36049       Terry Murray       13
# 13886       Terry Murray       26
# 28837     Terry O'Reilly        3
# 42412      Todd McLellan       26
# 7493       Todd McLellan       28
# 18         Todd McLellan       22
# 7518         Todd Nelson       22
# 42322       Todd Reirden       15
# 45388       Todd Reirden       88
# ...

# %%
s_coach_df[['first_name','last_name']]= s_coach_df['head_coach'].str.split(' ',n=1, expand= True)
s_coach_df
# Out:
#              head_coach  team_id first_name   last_name
# 7527         Adam Oates        1       Adam       Oates
# 9957         Adam Oates       15       Adam       Oates
# 24918         Al Arbour        2         Al      Arbour
# 29030        Al MacNeil       20         Al     MacNeil
# 44019  Alain Nasreddine        1      Alain  Nasreddine
# ...                 ...      ...        ...         ...
# 41342               NaN       10        NaN         NaN
# 41500               NaN       18        NaN         NaN
# 41661               NaN       16        NaN         NaN
# 41770               NaN        3        NaN         NaN
# 41771               NaN        9        NaN         NaN
#
# [252 rows x 4 columns]

# %%
s_coach_df= s_coach_df.dropna(subset=['first_name'])
s_coach_df
# Out:
#               head_coach  team_id first_name   last_name
# 7527          Adam Oates        1       Adam       Oates
# 9957          Adam Oates       15       Adam       Oates
# 24918          Al Arbour        2         Al      Arbour
# 29030         Al MacNeil       20         Al     MacNeil
# 44019   Alain Nasreddine        1      Alain  Nasreddine
# ...                  ...      ...        ...         ...
# 14          Travis Green       23     Travis       Green
# 26253       Trent Yawney       16      Trent      Yawney
# 21302      Wayne Gretzky       27      Wayne     Gretzky
# 48041  Willie Desjardins       26     Willie  Desjardins
# 139    Willie Desjardins       23     Willie  Desjardins
#
# [239 rows x 4 columns]
